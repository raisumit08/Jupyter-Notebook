# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('COVID-19_Vaccination_Trends_in_the_United_States_National_and_Jurisdictional.csv')

# %%
df.head()
# Out:
#          Date date_type  MMWR_week Location  Administered_Daily
# 0  04/26/2023    Report         17       OR                5506  \
# 1  04/26/2023    Report         17       MT                1159
# 2  04/26/2023    Report         17       VT                1403
# 3  04/26/2023    Report         17       GU                 231
# 4  04/26/2023    Report         17       MO                5653
#
#    Administered_Cumulative  Administered_7_Day_Rolling_Average
# 0                  9367024                                 NaN  \
# 1                  1866938                                 NaN
# 2                  1757365                                 NaN
# 3                   399659                                 NaN
# 4                 10492844                                 NaN
#
#    Admin_Dose_1_Daily  Admin_Dose_1_Cumulative
# 0                 849                  3456543  \
# 1                 148                   731067
# 2                 124                   623529
# ...
